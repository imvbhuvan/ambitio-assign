# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GEMINI_API_KEY'] = os.getenv('GEMINI_API_KEY')

# %%
import os
from google import genai

# The SDK automatically draws from the GEMINI_API_KEY environment variable
client = genai.Client()

response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents='Explain mixture of experts architecture in LLMs in bullet points'
)

print(response.text)
# Out:
# The **Mixture of Experts (MoE)** architecture is a design pattern that allows Large Language Models to be massive in terms of total parameter count while keeping the computational cost (inference time) relatively low.
#
# Here is an explanation of the architecture broken down into key components:
#
# ### 1. The Core Concept: Sparsity
# *   **Traditional Models (Dense):** In standard models (like GPT-3), every parameter is used for every single word generated. This makes them computationally expensive.
# *   **MoE Models (Sparse):** Instead of one giant neural network, the model consists of many smaller "expert" networks. For any given input, only a small subset of these experts is activated.
# *   **Efficiency:** This allows the model to have hundreds of billions of parameters while only "spending" the compute of a much smaller model per token.
#
# ### 2. Key Architectural Components
# *   **Experts:** These are typically Feed-Forward Networks (FFNs) distributed throughout the model layers. Each expert learns to specialize in different types of data (e.g., coding, creative writing, or mathematical logic).
# *   **Gating Network (Router):** This is the "traffic controller" of the model. For every incoming token, the router decides which experts are best suited to process it. It assigns a weight to the top-$k$ experts (usually $k=1$ or $2$).
# *   **Expert Parallelism:** Because different experts are used for different tokens, they can be spread across different GPU memories, allowing models to exceed the capacity of a single graphics card.
#
# ### 3. How It Works (Step-by-Step)
# 1.  **Input:** A token (a word or part of a word) enters a layer.
# 2.  **Routing:** The Gating Network calculates which experts have the highest probability of handling this specific token effectively.
# 3.  **Activation:** Only the chosen experts perform the computation for that token.
# 4.  **Weighted Sum:** The outputs of the selected experts are combined (weighted by the router’s confidence) to produce the final output for that layer.
# 5.  **Passing Forward:** The result is passed to the next layer, where the process repeats.
#
# ### 4. Benefits
# *   **Faster Inference:** Because only a fraction of the parameters are active at once, the model generates text faster than a "dense" model of the same total size.
# *   **Improved Performance:** By specializing, experts can achieve higher accuracy on specific tasks than a generic, dense network might.
# *   **Scaling:** It allows developers to scale models significantly in capacity without a linear increase in the energy or time required to run them.
#
# ### 5. Challenges and Drawbacks
# *   **VRAM Intensity:** Even though the *compute* is low, the *memory* requirements are massive. You must load all experts into VRAM, which requires many high-end GPUs.
# *   **Training Complexity:** Training MoE models is notoriously difficult. Experts can become unbalanced (e.g., one expert gets all the work while others remain "lazy"), requiring complex "load balancing" loss functions.
# *   **Fine-tuning Difficulty:** MoE models are often harder to fine-tune than dense models because the gating network needs to learn how to assign tasks correctly without disrupting existing expert specializations.
#
# ### Famous Examples
# *   **Mixtral 8x7B:** A popular open-weights model that uses 8 experts, choosing 2 per token, resulting in a model that performs like a much larger dense model while being faster to run.
# *   **GPT-4:** While not officially confirmed in detail by OpenAI, it is widely believed by industry researchers to be an MoE architecture.
